# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv('Placement1.csv')
dataset.drop(columns=['Student_ID'], inplace=True)
dataset.head(3)
# Out:
#    CGPA   IQ  Placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='CGPA', y='IQ', data=dataset, hue='Placement')
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset['Placement']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=30)

# %%
from sklearn.linear_model import Perceptron

# %%
pr = Perceptron(alpha=1)
pr.fit(x_train, y_train)
# Out:
# Perceptron(alpha=1)

# %%
pr.score(x_train, y_train)*100, pr.score(x_test, y_test)*100
# Out:
# (47.5, 60.0)

# %%
plt.figure(figsize=(4,3))
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=pr)
plt.show()
# Out:
# C:\Users\ACER\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
